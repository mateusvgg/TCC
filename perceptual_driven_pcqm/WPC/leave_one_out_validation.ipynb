# %%
import torch
import joblib
from tqdm import tqdm
import pandas as pd
import numpy as np
from sklearn.linear_model import PoissonRegressor
from sklearn.svm import SVR, NuSVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy.stats import spearmanr, pearsonr

# %%
x_train = torch.load('../data/X_tensor_WPC_cpu.pt')
y_train = torch.load('../data/y_tensor_WPC.pt')
ref_names = joblib.load('../data/ref_names_WPC.pkl')
codec_names = joblib.load('../data/degradations_WPC.pkl')

# %%
X_train = [[v.detach().numpy() for v in x] for x in x_train]

# %%
refs = list(set(ref_names))
codecs = list(set(codec_names))

# %%
refs
# Out:
# ['biscuits',
#  'banana',
#  'puer_tea',
#  'glasses_case',
#  'litchi',
#  'pen_container',
#  'house',
#  'pineapple',
#  'tool_box',
#  'stone',
#  'statue',
#  'ping-pong_bat',
#  'cauliflower',
#  'honeydew_melon',
#  'ship',
#  'pumpkin',
#  'bag',
#  'mushroom',
#  'flowerpot',
#  'cake']

# %%
codecs
# Out:
# ['G-PCC (T)/S-PCC',
#  'V-PCC',
#  'Downsampling',
#  'G-PCC (O)/L-PCC',
#  'Gaussian noise']

# %%
# the key is the reference that is excluded from the group
groups_by_ref = {}
for ref in refs:
    xtrain, ytrain = [], []
    xtest, ytest = [], []
    for i, ref_name in enumerate(ref_names):
        if ref_name == ref:
            xtest.append(X_train[i])
            ytest.append(y_train[i])
            continue
        xtrain.append(X_train[i])
        ytrain.append(y_train[i])
    groups_by_ref[ref] = [xtrain, ytrain, xtest, ytest]

# %%
# the key is the reference that is excluded from the group
groups_by_codec = {}
for codec in codecs:
    xtrain, ytrain = [], []
    xtest, ytest = [], []
    for i, codec_name in enumerate(codec_names):
        if codec_name == codec:
            xtest.append(X_train[i])
            ytest.append(y_train[i])
            continue
        xtrain.append(X_train[i])
        ytrain.append(y_train[i])
    groups_by_codec[codec] = [xtrain, ytrain, xtest, ytest]

# %%
def get_nusvr_model():
    return NuSVR(
    nu=0.42857142857142855,
    kernel='rbf',
    gamma=1, # type: ignore
    degree=2,
    C=50
)

# %%
def get_svr_model():
    return SVR(
        kernel='rbf',
        gamma=1,  # type: ignore
        epsilon=1,
        degree=2,
        C=5
    )

# %%
def get_pr_model():
    return PoissonRegressor(
        solver='lbfgs',
        max_iter=10,
        fit_intercept=True,
        alpha=0.01
    )

# %%
models = ['nusvr', 'svr', 'pr']

# %%
results_by_ref = []
for ref_out, xy in tqdm(groups_by_ref.items()):
    result = {'group_out': ref_out}
    xtrain, ytrain = xy[0], xy[1]
    xtest, ytest = xy[2], xy[3]
    for model_name in models:
        if model_name == 'nusvr':
            model = get_nusvr_model()
        if model_name == 'svr':
            model = get_svr_model()
        if model_name == 'pr':
            model = get_pr_model()
        model.fit(xtrain, ytrain)
        ypred = model.predict(xtest)
        result[f'{model_name}-pearson'] = pearsonr(ytest, ypred)[0]
        result[f'{model_name}-spearman'] = spearmanr(ytest, ypred)[0]
        result[f'{model_name}-rmse'] = np.sqrt(mean_squared_error(ytest, ypred))
    results_by_ref.append(result)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#   5%|▌         | 1/20 [00:00<00:02,  8.70it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  10%|█         | 2/20 [00:00<00:04,  3.84it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  15%|█▌        | 3/20 [00:00<00:04,  4.13it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  20%|██        | 4/20 [00:00<00:03,  4.99it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  25%|██▌       | 5/20 [00:00<00:02,  5.47it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  30%|███       | 6/20 [00:01<00:02,  5.89it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  35%|███▌      | 7/20 [00:01<00:02,  6.41it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  45%|████▌     | 9/20 [00:01<00:01,  8.38it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  55%|█████▌    | 11/20 [00:01<00:00,  9.26it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  60%|██████    | 12/20 [00:01<00:00,  9.01it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  70%|███████   | 14/20 [00:01<00:00,  9.33it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  75%|███████▌  | 15/20 [00:02<00:00,  9.29it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  85%|████████▌ | 17/20 [00:02<00:00,  9.89it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  90%|█████████ | 18/20 [00:02<00:00,  9.59it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  95%|█████████▌| 19/20 [00:02<00:00,  9.17it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# 100%|██████████| 20/20 [00:02<00:00,  7.71it/s]

# %%
results_by_codec = []
for codec_out, xy in tqdm(groups_by_codec.items()):
    result = {'group_out': codec_out}
    xtrain, ytrain = xy[0], xy[1]
    xtest, ytest = xy[2], xy[3]
    for model_name in models:
        if model_name == 'nusvr':
            model = get_nusvr_model()
        if model_name == 'svr':
            model = get_svr_model()
        if model_name == 'pr':
            model = get_pr_model()
        model.fit(xtrain, ytrain)
        ypred = model.predict(xtest)
        result[f'{model_name}-pearson'] = pearsonr(ytest, ypred)[0]
        result[f'{model_name}-spearman'] = spearmanr(ytest, ypred)[0]
        result[f'{model_name}-rmse'] = np.sqrt(mean_squared_error(ytest, ypred))
    results_by_codec.append(result)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  40%|████      | 2/5 [00:00<00:00,  8.93it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  60%|██████    | 3/5 [00:00<00:00,  7.98it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
#  80%|████████  | 4/5 [00:00<00:00,  6.19it/s]/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# 100%|██████████| 5/5 [00:00<00:00,  6.17it/s]

# %%
df_results_by_ref = pd.DataFrame(results_by_ref)
df_results_by_codec = pd.DataFrame(results_by_codec)

# %%
to_concat_by_ref = {
    'group_out': 'mean',
    'nusvr-pearson': df_results_by_ref.loc[:, 'nusvr-pearson'].mean(),
    'nusvr-spearman': df_results_by_ref.loc[:, 'nusvr-spearman'].mean(),
    'nusvr-rmse': df_results_by_ref.loc[:, 'nusvr-rmse'].mean(),
    'svr-pearson': df_results_by_ref.loc[:, 'svr-pearson'].mean(),
    'svr-spearman': df_results_by_ref.loc[:, 'svr-spearman'].mean(),
    'svr-rmse': df_results_by_ref.loc[:, 'svr-rmse'].mean(),
    'pr-pearson': df_results_by_ref.loc[:, 'pr-pearson'].mean(),
    'pr-spearman': df_results_by_ref.loc[:, 'pr-spearman'].mean(),
    'pr-rmse': df_results_by_ref.loc[:, 'pr-rmse'].mean()
}

# %%
to_concat_by_codec = {
    'group_out': 'mean',
    'nusvr-pearson': df_results_by_codec.loc[:, 'nusvr-pearson'].mean(),
    'nusvr-spearman': df_results_by_codec.loc[:, 'nusvr-spearman'].mean(),
    'nusvr-rmse': df_results_by_codec.loc[:, 'nusvr-rmse'].mean(),
    'svr-pearson': df_results_by_codec.loc[:, 'svr-pearson'].mean(),
    'svr-spearman': df_results_by_codec.loc[:, 'svr-spearman'].mean(),
    'svr-rmse': df_results_by_codec.loc[:, 'svr-rmse'].mean(),
    'pr-pearson': df_results_by_codec.loc[:, 'pr-pearson'].mean(),
    'pr-spearman': df_results_by_codec.loc[:, 'pr-spearman'].mean(),
    'pr-rmse': df_results_by_codec.loc[:, 'pr-rmse'].mean()
}

# %%
df_conc_by_ref = pd.DataFrame([to_concat_by_ref])
df_results_by_ref = pd.concat([df_results_by_ref, df_conc_by_ref])

# %%
df_conc_by_codec = pd.DataFrame([to_concat_by_codec])
df_results_by_codec = pd.concat([df_results_by_codec, df_conc_by_codec])

# %%
df_results_by_ref
# Out:
#          group_out  nusvr-pearson  nusvr-spearman  nusvr-rmse  svr-pearson  \
# 0         biscuits       0.824190        0.840446   13.675668     0.827944
# 1           banana       0.606233        0.552394   17.685598     0.626440
# 2         puer_tea       0.625697        0.671645   25.361042     0.638017
# 3     glasses_case       0.804486        0.811759   16.023422     0.802631
# 4           litchi       0.782992        0.752252   16.868621     0.790947
