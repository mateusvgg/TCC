# %%
import torch
import numpy as np
from sklearn.linear_model import PoissonRegressor
from sklearn.svm import SVR, NuSVR
from sklearn.model_selection import RandomizedSearchCV, train_test_split

# %%
x_train = torch.load('../data/X_tensor_WPC_cpu.pt')
y_train = torch.load('../data/y_tensor_WPC.pt')

# %%
X_train = [[v.detach().numpy() for v in x] for x in x_train]

# %%
param_grid_pr = {
    'alpha': [0.01, 0.1, 0.5, 1, 5, 10, 20, 50, 100],
    'fit_intercept': [True, False],
    'solver': ['lbfgs', 'newton-cholesky'],
    'max_iter': [10, 50, 100, 150, 200],
}

# %%
param_grid_nusvr = {
    'C': [0.1, 1, 5, 10, 50, 100],
    'gamma': [0.01, 0.1, 1, 10],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'degree': [1, 2, 3, 4],
    'nu': np.linspace(0, 1, 15)
}

# %%
param_grid_svr = {
    'C': [0.1, 1, 5, 10, 50, 100],
    'gamma': [0.01, 0.1, 1, 10],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'degree': [1, 2, 3, 4],
    'epsilon': [0.01, 0.1, 1]
}

# %%
nusvr_regressor = NuSVR()
svr_regressor = SVR()
pr_regressor = PoissonRegressor()

# %%
n_iter = 800
scoring = 'neg_root_mean_squared_error'

# %%
random_search_nusvr = RandomizedSearchCV(
    nusvr_regressor,
    param_distributions=param_grid_nusvr,
    n_iter=n_iter,
    cv=5,
    n_jobs=-1,
    scoring=scoring
)

# %%
random_search_svr = RandomizedSearchCV(
    svr_regressor,
    param_distributions=param_grid_svr,
    n_iter=n_iter,
    cv=5,
    n_jobs=-1,
    scoring=scoring
)

# %%
random_search_pr = RandomizedSearchCV(
    pr_regressor,
    param_distributions=param_grid_pr,
    n_iter=n_iter,
    cv=5,
    n_jobs=-1,
    scoring=scoring,
)

# %%
random_search_nusvr.fit(X_train, y_train)
# Out:
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 250 fits failed out of a total of 4000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 250 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/svm/_base.py", line 180, in fit
#     self._validate_params()
#   File "/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/base.py", line 570, in _validate_params
#     validate_parameter_constraints(
#   File "/home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'nu' parameter of NuSVR must be a float in the range (0.0, 1.0]. Got 0.0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [  -21.24734057   -34.25756005   -24.22108351   -22.91685273
#    -22.99020658            nan   -22.81565673   -20.64055811
#    -22.80126561   -15.91857153   -15.91171063   -15.58848761
#    -22.96428533   -22.94684331   -21.22969401   -22.99910688
#    -19.28082789 -1090.60056914   -22.97904423   -18.0047464
#    -15.92788962            nan   -20.22880852   -17.08410675
#             nan   -16.37145424   -16.0665024    -22.73240623
#    -23.00775384   -15.87181944   -20.76416867   -22.17307022
#    -22.56137598   -19.13682622   -15.90441217   -15.55967555
#    -18.57701298   -19.0832619    -15.91215802   -15.92226584
#    -17.5287733    -16.02471677   -19.6114058    -22.8194236
#             nan   -20.58529865   -16.51170254   -22.03223779
#    -21.27439423   -22.98107425   -21.74380282   -18.11761984
#    -19.92399597   -17.51888218   -17.25039153   -17.75915002
#    -20.76307727   -22.16966984   -18.86914387   -22.94047008
#  -1526.27159662            nan   -38.44492345   -18.85986258
#    -22.57517092   -22.69437171   -15.58902911   -22.92479723
#    -22.03223779   -15.85685398   -31.07758074   -16.0665024
#    -17.32936248            nan   -22.88152535   -22.99711546
#    -15.75307803   -15.90448709   -15.92226584   -22.63476804
#    -15.56450312   -15.88388566   -15.89762995   -15.8096914
#             nan   -46.16570343   -17.32751427   -16.33262986
#    -15.85235709  -106.98544019   -38.51810618   -16.31926675
#    -22.90976027   -23.00050054   -17.5033204    -16.37718025
#    -22.32201416   -16.49197761   -27.85164137   -16.02998284
#   -859.40445469   -17.32751428   -17.4409478    -22.32201416
#    -15.9105649    -22.32201416   -22.93422449   -15.91760801
#    -17.62980939   -15.90448709   -15.88388566   -15.86193344
#    -22.96606988   -23.00711454   -22.14085811   -19.71924991
#    -19.6114058    -17.88327334   -18.01535964   -18.62479764]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=NuSVR(), n_iter=800, n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 5, 10, 50, 100],
#                                         'degree': [1, 2, 3, 4],
#                                         'gamma': [0.01, 0.1, 1, 10],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid'],
#                                         'nu': array([0.        , 0.07142857, 0.14285714, 0.21428571, 0.28571429,
#        0.35714286, 0.42857143, 0.5       , 0.57142857, 0.64285714,
#        0.71428571, 0.78571429, 0.85714286, 0.92857143, 1.        ])},
#                    scoring='neg_root_mean_squared_error')

# %%
random_search_svr.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVR(), n_iter=800, n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 5, 10, 50, 100],
#                                         'degree': [1, 2, 3, 4],
#                                         'epsilon': [0.01, 0.1, 1],
#                                         'gamma': [0.01, 0.1, 1, 10],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']},
#                    scoring='neg_root_mean_squared_error')

# %%
random_search_pr.fit(X_train, y_train)
# Out:
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:306: UserWarning: The total space of parameters 180 is smaller than n_iter=800. Running 180 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# /home/mateusvg_db/TCC/tccVenv2/lib/python3.10/site-packages/sklearn/linear_model/_glm/glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# RandomizedSearchCV(cv=5, estimator=PoissonRegressor(), n_iter=800, n_jobs=-1,
#                    param_distributions={'alpha': [0.01, 0.1, 0.5, 1, 5, 10, 20,
#                                                   50, 100],
#                                         'fit_intercept': [True, False],
#                                         'max_iter': [10, 50, 100, 150, 200],
#                                         'solver': ['lbfgs', 'newton-cholesky']},
#                    scoring='neg_root_mean_squared_error')

# %%
print('Best params for NuSVR')
print(random_search_nusvr.best_params_)
# Out:
# Best params for NuSVR
# {'nu': 0.42857142857142855, 'kernel': 'rbf', 'gamma': 1, 'degree': 2, 'C': 50}

# %%
# nusvr_params = {
# 'nu': 0.42857142857142855,
# 'kernel': 'rbf',
# 'gamma': 1,
# 'degree': 2,
# 'C': 50
# }

# %%
print('Best params for SVR')
print(random_search_svr.best_params_)
# Out:
# Best params for SVR
# {'kernel': 'rbf', 'gamma': 1, 'epsilon': 1, 'degree': 2, 'C': 5}

# %%
# svr_params_wpc = {
#     'kernel': 'rbf',
#     'gamma': 1,
#     'epsilon': 1,
#     'degree': 2,
#     'C': 5
# }

# %%
print('Best params for PoissonRegressor')
print(random_search_pr.best_params_)
# Out:
# Best params for PoissonRegressor
# {'solver': 'lbfgs', 'max_iter': 10, 'fit_intercept': True, 'alpha': 0.01}

# %%
# pr_params = {
# 'solver': 'lbfgs',
# 'max_iter': 10,
# 'fit_intercept': True,
# 'alpha': 0.01
# }
